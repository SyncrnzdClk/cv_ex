# %% [markdown]
# # Computer Vision Lecture - Exercise 5 Part 2 - Recognition
# In this exercise, you will gain hands-on experience regarding object recognition. More specifically, we will develop our own simple person detector using methods from classical image processing!
#
# This notebook guides you through the relevant steps. When you see helper functions, you don't need to do anything - they are already implemented. The functions you need to implement are indicated as Exercise Function. Sometimes, you can find Hints - these are written upside-down so you can first try to find the solution without reading them.
#
# Good luck and lot's of fun!

# %% [markdown]
# ## Preliminaries
# Let's first install dependencies and import the required libaries.

# %%
# !pip install faiss-cpu --no-cache --quiet


import os
import numpy as np
from PIL import Image
import torch
import torchvision.datasets as datasets
from tqdm import tqdm
from skimage.feature import hog
from sklearn.svm import SVC
import faiss      # fast kNN search

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# set random seed for reproducability
np.random.seed(42)

# %% [markdown]
# First, we load a the [Penn-Fudan Pedestrian Dataset](https://www.cis.upenn.edu/~jshi/ped_html/) and visualize some of its images.

# %%
###########################
##### Helper Function #####
###########################
class PennFudanDataset(torch.utils.data.Dataset):
  ''' Penn-Fudan Pedestrian dataset.
  
  Args:
  root (str): path to data directory
  split (str): dataset split, "train" or "val"
  '''
  def __init__(self, root, split='train'):
    self.root = root
    
    # download dataset if needed
    # if not os.path.isdir(self.root):
    #   !wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip --directory-prefix=$self.root
    #   !unzip -qq $self.root/PennFudanPed.zip -d $self.root

    # load all image files, sorting them to
    # ensure that they are aligned
    imgs = list(sorted(os.listdir(os.path.join(root, "PennFudanPed","PNGImages"))))
    masks = list(sorted(os.listdir(os.path.join(root, "PennFudanPed", "PedMasks"))))

    # split into train and validation set
    ntrain = int(0.8*len(imgs))
    if split == 'train':
      self.imgs = imgs[:ntrain]
      self.masks = masks[:ntrain]
    elif split == 'val':
      self.imgs = imgs[ntrain:]
      self.masks = masks[ntrain:]
    else:
      raise AttributeError('split must be "train" or "val".')

  def __getitem__(self, idx):
    # load images and masks
    img_path = os.path.join(self.root, "PennFudanPed", "PNGImages", self.imgs[idx])
    mask_path = os.path.join(self.root, "PennFudanPed", "PedMasks", self.masks[idx])
    img = Image.open(img_path).convert("RGB")
    # note that we haven't converted the mask to RGB,
    # because each color corresponds to a different instance
    # with 0 being background
    
    mask = Image.open(mask_path)
    # convert the PIL Image into a numpy array
    mask = np.array(mask)
    # instances are encoded as different colors
    obj_ids = np.unique(mask)
    # first id is the background, so remove it
    obj_ids = obj_ids[1:]

    # split the color-encoded mask into a set
    # of binary masks
    masks = mask == obj_ids[:, None, None]

    # get bounding box coordinates for each mask
    num_objs = len(obj_ids)
    boxes = []
    for i in range(num_objs):
        pos = np.where(masks[i])
        xmin = np.min(pos[1])
        xmax = np.max(pos[1])
        ymin = np.min(pos[0])
        ymax = np.max(pos[0])
        boxes.append([xmin, ymin, xmax, ymax])

    return img, {'boxes': boxes}

  def __len__(self):
    return len(self.imgs)

# %%
###########################
##### Helper Function #####
###########################
def get_width_and_height(box):
  """ Helper function to determine size of bounding boxes.

  Args:
  box (iterable): (left, upper, right, lower) pixel coordinate
  """
  return box[2]-box[0], box[3]-box[1]

def draw_box(ax, box, color='r'):
  ''' Plot box on axes.
  
  Args:
  ax (matplotlib.axes.Axes): axes to add box to
  box (iterable): (left, upper, right, lower) pixel coordinate
  color (str or list): edgecolor of the box
  '''
  anchor = box[:2]
  W, H = get_width_and_height(box)
  patch = Rectangle(anchor, width=W, height=H, edgecolor=color, facecolor='none')
  ax.add_patch(patch)

# %%
train_set = PennFudanDataset('data', split='train') 
for i in range(2):
  img, annotation = train_set[i]
  fig, ax = plt.subplots(1)
  ax.set_axis_off()
  ax.imshow(img)
  for box in annotation['boxes']:
    draw_box(ax, box)

# %% [markdown]
# ## Developing a Person Detector
#
# Okay, we have our dataset so let's start to program our person detector! We will do this using a sliding window approach. The steps that we have to take are:
#
# 1.   Get **positive** training examples, i.e. image patches that contain a person.
# 2.   Get **negative** training examples, i.e. image patches that do not contain a (complete) person.
# 3.   Extract Histogram of Oriented Gradients (HOG) **features** to obtain a more robust image descriptor than the raw pixel values.
# 4.   **Train our preferred classifier** with this training data. We will implement a simple nearest neighbor search and a Support Vector Machine.
# 5.   Extract the image patches and HOG features from our validation image using a **sliding window approach and evaluate our classifier** on each patch to detect persons in the validation image.

# %% [markdown]
# ### Getting the Training Patches
#
# To obtain positive training examples, we can simply crop the training images according to the given bounding boxes.
# We also resize the crops to a given size to ensure that all of our patches have the same size.

# %%
###########################
##### Helper Function #####
###########################
def get_resized_patch(img, box, patch_size):
  ''' Crop patch from image and resize it to given size.
  
  Args:
  img (PIL.Image.Image): image
  box (iterable): (left, upper, right, lower) pixel coordinate
  patch_size (tuple): width, height of resized patch
  '''
  assert isinstance(img, Image.Image), 'img needs to be PIL.Image.Image'
  crop = img.crop(box)  
  patch = crop.resize(patch_size)
  return patch

# %% [markdown]
# Next, we need to get negative examples for training. Complete the function below, such that it places a box of a given size at a random location in the image. Ensure that the whole box is within the image boundaries. The function should return the (left, upper, right, lower) pixel coordinates of the box.

# %%
###########################
#### Exercise Function ####
###########################
def get_random_box(boxsize, imsize):
  """ Returns randomly located box with same size as box. 
  
  Args:
  boxsize (tuple): width, height of box
  imsize (tuple): width, height of image / image boundaries
  """
  W, H = imsize

  # Insert your code here
  left = np.random.randint(W-boxsize[0])
  upper = np.random.randint(H-boxsize[1])
  
  box = [left, upper, left + boxsize[0], upper + boxsize[1]]
  assert all(b >= 0 for b in box) and (box[2] < W) and (box[3] < H), f'Box {box} out of image bounds {W, H}.'
  return box

# %% [markdown]
# In addition to these rather simple negative examples, let's also include some more challenging negative examples to improve the quality of our classifier later on. We construct hard negative examples by adding a small offset to the ground truth boxes. Thereby, the negative examples are close to positive detections.
# Complete the function below, such that it adds a small random offset to a given box. The minimal offset in height/width should be 1 pixel and the maximal height/width offset should not exceed 20% of the box height/width.

# %%
###########################
#### Exercise Function ####
###########################
def add_offset_to_box(box, imsize):
  """ Add a small random integer offset to the box.

  Args:
  box (iterable): (left, upper, right, lower) pixel coordinate
  imsize (tuple): width, height of image / image boundaries
  """
  W, H = imsize
  box_W, box_H = get_width_and_height(box)

  # Insert your code here
  width_offset = np.random.random_integers(1, box_W * 0.2)
  height_offset = np.random.random_integers(1, box_H * 0.2)
  width_offset *= np.random.choice([-1, 1])
  height_offset *= np.random.choice([-1, 1])

  off_box = [box[0]+width_offset, box[1]+height_offset, box[2]+width_offset, box[3]+height_offset]

  # ensure to stay within image boundaries / do not mind changing size slightly
  off_box[0] = max(0, off_box[0])
  off_box[1] = max(0, off_box[1])
  off_box[2] = min(W-1, off_box[2])  
  off_box[3] = min(H-1, off_box[3])

  assert all(b >= 0 for b in off_box) and (off_box[2] < W) and (off_box[3] < H), f'Box {off_box} out of image bounds {W, H}.'

  return off_box

# %% [markdown]
# With these tools at hand, we can collect our training patches from the images.

# %%
###########################
##### Helper Function #####
###########################
def imgs_to_patches(train_set, patch_size, n_random_negatives=3, n_hard_negatives=3):
  positives = []
  negatives = []
  orig_sizes = []
  for img, annotation in tqdm(train_set):
    for box in annotation['boxes']:
      
      # keep track of original box sizes for sliding window approach later
      orig_sizes.append(np.array(get_width_and_height(box)))

      # extract positives
      positives.append(get_resized_patch(img, box, patch_size))

      # add some random negatives
      for _ in range(n_random_negatives):
        boxsize = get_width_and_height(box)
        mod_box = get_random_box(boxsize, img.size)
        negatives.append(get_resized_patch(img, mod_box, patch_size))

      # add some hard negatives by adding noise on box
      for _ in range(n_hard_negatives):
        mod_box = add_offset_to_box(box, img.size)
        negatives.append(get_resized_patch(img, mod_box, patch_size))
  
  return positives, negatives, orig_sizes

# %%
patch_size = (50, 150)          # hyperparameter
positives, negatives, orig_sizes = imgs_to_patches(train_set, patch_size)
# Out:
#   0%|          | 0/136 [00:00<?, ?it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 28.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 49.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 23.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 63.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 24.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 57.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 30.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 57.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 31.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 55.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 7.800000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 23.8 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 26.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 55.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 7.6000000000000005 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 21.0 + 1) instead
#   app.launch_new_instance()
#   4%|▎         | 5/136 [00:00<00:02, 44.11it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 27.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 17.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 55.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 21.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 30.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 60.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 6.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 16.8 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 15.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 36.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 29.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 58.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 28.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 54.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 24.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 56.800000000000004 + 1) instead
#   app.launch_new_instance()
#   7%|▋         | 10/136 [00:00<00:03, 40.83it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 32.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 56.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 27.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 58.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 22.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 53.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 33.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 56.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 34.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 56.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 31.0 + 1) instead
#   from ipykernel import kernelapp as app
#  11%|█         | 15/136 [00:00<00:03, 38.94it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 25.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 59.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 24.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 53.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 16.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 25.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 57.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 27.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 50.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 29.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 59.6 + 1) instead
#   app.launch_new_instance()
#  14%|█▍        | 19/136 [00:00<00:03, 37.58it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 33.800000000000004 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 29.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 58.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 6.800000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 14.8 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 4.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 13.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 19.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 56.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 23.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 27.8 + 1) instead
#   from ipykernel import kernelapp as app
#  17%|█▋        | 23/136 [00:00<00:03, 36.56it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 33.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 34.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 10.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 33.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 12.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 37.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 9.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 40.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 12.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 37.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 13.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 40.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 62.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 18.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 29.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 26.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 60.6 + 1) instead
#   app.launch_new_instance()
#  21%|██        | 28/136 [00:00<00:02, 38.67it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 24.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 55.800000000000004 + 1) instead
#   app.launch_new_instance()
#  24%|██▎       | 32/136 [00:00<00:03, 32.20it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 58.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 28.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 26.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 29.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 59.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 52.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 17.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 46.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 12.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 40.0 + 1) instead
#   app.launch_new_instance()
#  26%|██▋       | 36/136 [00:01<00:03, 31.72it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 3.8000000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 14.4 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 36.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 12.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 34.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 20.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 15.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 19.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 51.6 + 1) instead
#   app.launch_new_instance()
#  29%|██▉       | 40/136 [00:01<00:03, 31.22it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 17.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 14.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 13.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 18.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 20.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 16.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 18.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 17.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 57.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 28.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 72.60000000000001 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 13.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 49.0 + 1) instead
#   app.launch_new_instance()
#  32%|███▏      | 44/136 [00:01<00:03, 29.68it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 19.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 14.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 18.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 14.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 44.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 42.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 8.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 27.8 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 19.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 11.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 46.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 9.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 22.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 44.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 57.6 + 1) instead
#   app.launch_new_instance()
#  35%|███▌      | 48/136 [00:01<00:03, 25.82it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 20.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 20.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 41.400000000000006 + 1) instead
#   app.launch_new_instance()
#  38%|███▊      | 51/136 [00:01<00:03, 26.36it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 20.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 52.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 22.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 43.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 41.6 + 1) instead
#   app.launch_new_instance()
#  40%|███▉      | 54/136 [00:01<00:03, 26.73it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 70.4 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 55.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 14.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 54.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 54.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 53.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 15.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 54.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 9.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 30.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 8.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 26.8 + 1) instead
#   app.launch_new_instance()
#  42%|████▏     | 57/136 [00:01<00:03, 25.35it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 23.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 74.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 4.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 17.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 10.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 35.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 10.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 35.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 11.200000000000001 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 2.4000000000000004 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 9.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 3.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 10.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 5.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 16.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 60.0 + 1) instead
#   app.launch_new_instance()
#  44%|████▍     | 60/136 [00:01<00:02, 26.09it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 59.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 60.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 16.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 58.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 3.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 1.2000000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 3.8000000000000003 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 1.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 4.0 + 1) instead
#   app.launch_new_instance()
#  46%|████▋     | 63/136 [00:02<00:02, 26.15it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 23.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 62.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 19.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 15.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 64.60000000000001 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 10.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 25.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 16.2 + 1) instead
#   from ipykernel import kernelapp as app
#  49%|████▊     | 66/136 [00:02<00:02, 26.94it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 16.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
#  51%|█████▏    | 70/136 [00:02<00:02, 29.73it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 5.800000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 13.4 + 1) instead
#   app.launch_new_instance()
#  54%|█████▍    | 74/136 [00:02<00:01, 32.03it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 22.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 18.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 62.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 50.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 34.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 44.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 42.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 30.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 27.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 33.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 66.4 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 15.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 69.8 + 1) instead
#   app.launch_new_instance()
#  57%|█████▋    | 78/136 [00:02<00:02, 25.89it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 17.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 51.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 30.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 25.200000000000003 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 54.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 48.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 68.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 65.4 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 13.200000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 64.8 + 1) instead
#   app.launch_new_instance()
#  60%|█████▉    | 81/136 [00:02<00:02, 24.48it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 50.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 45.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 50.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 14.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 25.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 75.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 71.60000000000001 + 1) instead
#   app.launch_new_instance()
#  62%|██████▏   | 84/136 [00:02<00:02, 22.76it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 22.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 21.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 8.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 20.400000000000002 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 53.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 13.4 + 1) instead
#   from ipykernel import kernelapp as app
#  65%|██████▍   | 88/136 [00:03<00:01, 25.52it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 31.400000000000002 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 63.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 32.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 67.4 + 1) instead
#   app.launch_new_instance()
#  67%|██████▋   | 91/136 [00:03<00:01, 23.49it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 47.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 60.800000000000004 + 1) instead
#   app.launch_new_instance()
#  69%|██████▉   | 94/136 [00:03<00:01, 22.56it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 30.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 52.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 26.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 36.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 33.6 + 1) instead
#   from ipykernel import kernelapp as app
#  71%|███████▏  | 97/136 [00:03<00:01, 20.40it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 30.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 6.2 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 13.8 + 1) instead
#   app.launch_new_instance()
#  74%|███████▍  | 101/136 [00:03<00:01, 23.92it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 61.0 + 1) instead
#   app.launch_new_instance()
#  77%|███████▋  | 105/136 [00:03<00:01, 27.21it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 66.60000000000001 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 65.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 24.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 34.800000000000004 + 1) instead
#   from ipykernel import kernelapp as app
#  80%|████████  | 109/136 [00:03<00:00, 29.25it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 21.6 + 1) instead
#   from ipykernel import kernelapp as app
#  83%|████████▎ | 113/136 [00:03<00:00, 31.94it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 11.4 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 35.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 35.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 5.2 + 1) instead
#   from ipykernel import kernelapp as app
#  86%|████████▌ | 117/136 [00:04<00:00, 31.82it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 43.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 44.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 23.400000000000002 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 22.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 10.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 30.400000000000002 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 4.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 11.4 + 1) instead
#   app.launch_new_instance()
#  89%|████████▉ | 121/136 [00:04<00:00, 31.90it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 69.60000000000001 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 11.0 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 31.200000000000003 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 11.600000000000001 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 32.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 50.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 25.6 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 67.8 + 1) instead
#   app.launch_new_instance()
#  92%|█████████▏| 125/136 [00:04<00:00, 30.68it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 48.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 27.0 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 21.8 + 1) instead
#   from ipykernel import kernelapp as app
#  95%|█████████▍| 129/136 [00:04<00:00, 31.93it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 52.400000000000006 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: This function is deprecated. Please call randint(1, 9.8 + 1) instead
#   from ipykernel import kernelapp as app
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 52.0 + 1) instead
#   app.launch_new_instance()
#  98%|█████████▊| 133/136 [00:04<00:00, 30.24it/s]/root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 41.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 39.6 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 49.2 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 59.800000000000004 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 17.8 + 1) instead
#   app.launch_new_instance()
# /root/miniconda3/envs/lecturecv-ex05/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: This function is deprecated. Please call randint(1, 35.4 + 1) instead
#   app.launch_new_instance()
# 100%|██████████| 136/136 [00:04<00:00, 29.03it/s]

# %% [markdown]
# Let's take a look at some of the positive and some of the negative patches to ensure everything is correct.

# %%
fig, ax = plt.subplots(1, 2)
ax[0].set_axis_off()
ax[0].imshow(np.concatenate([np.array(p) for p in positives[:5]], 1))

ax[1].set_axis_off()
ax[1].imshow(np.concatenate([np.array(n) for n in negatives[:5]], 1))

# %% [markdown]
# Do both positive and negative samples look reasonable? If they do, we can advance with the next step.

# %% [markdown]
# ### Extracting HOG features
#
# In the next steps, we convert the RGB pixel values from the image patches to more robust HOG features.

# %%
###########################
##### Helper Function #####
###########################
def get_hog(img, **kwargs):
  """ Extract HOG features with predefined settings.

  Args:
  img (np.ndarray): image with channel dimension last (HxWx3)
  """
  return hog(img, orientations=8, pixels_per_cell=(16, 16), cells_per_block=(1, 1), **kwargs)

# visualize HOG for one image
img = np.array(positives[0])
fd, hog_image = get_hog(img, visualize=True)      # if visualize=True this function returns the descriptors + the image, otherwise it only returns the descriptors

fig, ax = plt.subplots(1, 2)
ax[0].imshow(img)
ax[1].imshow(hog_image, cmap=plt.cm.gray)

# %%
fds_pos = []
for p in tqdm(positives, position=0, leave=True, desc='Extract HOG features for positive samples'):
  fds_pos.append(get_hog(p))

fds_neg = []
for n in tqdm(negatives, position=0, leave=True, desc='Extract HOG features for negative samples'):
  fds_neg.append(get_hog(n))
# Out:
# Extract HOG features for positive samples: 100%|██████████| 354/354 [00:00<00:00, 707.33it/s]
# Extract HOG features for negative samples: 100%|██████████| 2124/2124 [00:03<00:00, 699.72it/s]

# %% [markdown]
# ### Training the classifiers
#
# First, we construct our training set using the HOG feature descriptors from the previous step.

# %%
X = np.stack(fds_pos + fds_neg)
y = np.concatenate([np.ones(len(positives), dtype=np.bool), np.zeros(len(negatives), dtype=np.bool)])

# %% [markdown]
# First, we train a simple nearest neighbor classifier. Since the sliding window approach will give us a lot of patches per image, a naive nearest neighbor approach can be very slow. Therefore, we use the [Faiss Library](https://github.com/facebookresearch/faiss) which is optimized for exactly such applications.

# %%
###########################
##### Helper Function #####
###########################
def init_nn_search(X):
  """ Initialize the index for a nearest neighbor search.

  Args:
  X (np.ndarray): training data
  """
  d = X.shape[1]
  quantizer = faiss.IndexFlatL2(d)                                  # measure L2 distance
  index = faiss.IndexIVFFlat(quantizer, d, 100, faiss.METRIC_L2)    # build the index

  index.train(X.astype(np.float32))
  index.add(X.astype(np.float32))                                   # add vectors to the index
  return index

index = init_nn_search(X)

# %% [markdown]
# Second, we train a support vector machine using `sklearn.svm.SVC`.

# %%
###########################
##### Helper Function #####
###########################
def train_svm(X, y):
  """ Train a support vector machine.

  Args:
  X (np.ndarray): training data
  y (np.ndarray): training labels
  """
  clf = SVC(class_weight='balanced')        # use balanced weight since we have more negatives than positives
  clf.fit(X, y)
  return clf

svm = train_svm(X, y)

# %% [markdown]
# ### Evaluating the classifiers
#
# In order to evaluate our classifiers, we need to extract the image patches and their HOG features from the target image, so that our target data is similar to our training data.
# We do this using a sliding window approach.
# Implement a function that extracts all crops of a given window size from an image in a sliding window manner. Similar to the training data, resize the crops to a given size and convert these patches to HOG features.
# Your function should return two `numpy.ndarray`s. The first contains the feature descriptors of all patches in the image (Pxd), and the second contains the corresponding anchor, i.e. the (upper,left) pixel coordinate, of each patch (Px2).

# %%
###########################
#### Exercise Function ####
###########################
def img_to_hog_patches(img, window_size, patch_size, step_size=1):
  """ Extract hog feature patches from an image using a sliding window approach.

  Args:
  img (PIL.Image.Image): image
  window_size (tuple): width, height of window
  patch_size (tuple): width, height of resized patch
  step_size (int): step size of window (for faster evaluation)
  """
  
  # Insert your code here
  W, H = img.size
  fds = []
  anchors = []
  for left in range(0, int(W-window_size[0]), step_size):
    for upper in range(0, int(H-window_size[1]), step_size):
      box = [left, upper, left+window_size[0], upper+window_size[1]]
      cropped_img = img.crop(box)
      patch = cropped_img.resize(patch_size)
      fds.extend([get_hog(patch)])
      anchors.extend([(left, upper)])
  # convert to numpy arrays
  fds = np.stack(fds)
  anchors = np.stack(anchors)
  return fds, anchors

# %% [markdown]
# Now, let us evaluate our classifiers on some new images.

# %%
val_set = PennFudanDataset('data', split='val') 

N_imgs = 3
window_size = np.stack(orig_sizes).mean(0).astype(np.uint)      # use average size of training boxes as window size

for i in range(N_imgs):  
  img, ann = val_set[i]
  fds, anchors = img_to_hog_patches(img, window_size, patch_size, step_size=10)

  # evaluate NN search
  _, I = index.search(fds.astype(np.float32), 1)        # search nearest neighbor for each grid point
  is_positive = y[I]                                    # assign labels of training points
  
  mask = is_positive.reshape(-1, 1).repeat(2, 1)        # convert to mask for anchors
  anchors_nn = anchors[mask].reshape(-1, 2)

  # evaluate SVM
  k = 5
  scores = svm.predict(fds)
  idcs_sorted = np.argsort(scores)[::-1][:k]                # sort get top k predictions
  anchors_svm = anchors[idcs_sorted]

  # visualize the results
  fig, ax = plt.subplots(2)
  
  ax[0].imshow(img)
  for a in anchors_nn:
    box = (a[0], a[1], a[0]+window_size[0], a[1]+window_size[1])
    draw_box(ax[0], box, color='r')
  
  ax[1].imshow(img)
  for j, a in enumerate(anchors_svm):
    box = (a[0], a[1], a[0]+window_size[0], a[1]+window_size[1])
    color = 'r' if j == 0 else 'orange'
    draw_box(ax[1], box, color=color)
  
  plt.show()

# %% [markdown]
# Great job! While not perfect, HOG features combined with a simple classifier yield reasonable detections for this dataset.
# You now gained hands-on experience in the fields of image detection!
